# %%
#%pip install psycopg2 -q
# !pip3.14 uninstall psycopg2 -y && pip3.14 install psycopg2-binary -q
# Out:
# WARNING: Skipping psycopg2 as it is not installed.
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip3.14 install --upgrade pip

# %%
import psycopg2

def connect_to_postgres():
    try:
        # Note: http:// is not used for postgres connections, just the host IP/domain
        connection = psycopg2.connect(
            host="76.13.60.86",
            port="5432",
            user="ap_user_001", # "admin@a3gents.com",
            password="apuser!23", #"a3Admin...", # Replace with your full password
            dbname="accountplanning" #"mahalle_db" # Replace with your actual database name
        )
        print("Successfully connected to the database!")
        return connection
    except Exception as e:
        print(f"Error connecting to database: {e}")
        return None

# Example usage:
conn = connect_to_postgres()
if conn:
    print('Do something with the connection')
    conn.close()
# Out:
# Successfully connected to the database!
# Do something with the connection
